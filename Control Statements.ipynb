# %%
str='Python'
for i in str:
  if i=='o':
    pass
  else:
    print(i)
# Out:
# P
# y
# t
# h
# n

# %%
str='Python'
for i in str:
  if i=='h':
    break
  else:
    print(i)
# Out:
# P
# y
# t

# %%
list=[1,2,3,4,5,6,7]
for i in list:
  if i==5:
    pass
  else:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7

# %%
list=[1,2,3,4,5,6,7]
for i in list:
  if i==6:
    break
  else:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
tuple=(1,2,3,4,5,6,7)
for i in tuple:
  if i==5:
    pass
  else:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7

# %%
tuple=(1,2,3,4,5,6,7)
for i in list:
  if i==5:
    break
  else:
    print(i)
# Out:
# 1
# 2
# 3
# 4
